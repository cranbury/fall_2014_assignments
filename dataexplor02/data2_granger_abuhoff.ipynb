# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from IPython.display import Image
import os

# %%
data = pd.read_csv(os.path.join('africa_ph.csv'))

# %%
print data
# Out:
#      Unnamed: 0      PIDN        pH      ELEV      REF2      BSAN      LSTN  \
# 0            32  d9u06tdU -0.044436  0.904900 -0.352505 -0.710145 -0.371001
# 1            33  qsQFu3ef -0.455961  0.904900 -0.352505 -0.710145 -0.371001
# 2            34  C4kj5IMN -0.549490  0.971715 -0.352505 -0.702899 -0.399312
# 3            35  p1SCgsM8 -0.951662  0.971715 -0.352505 -0.702899 -0.399312
# 4            36  UqyLWYTl -0.427903  0.929399 -0.506494 -0.695652 -0.543779
# 5            37  HhLQiNKo -1.073249  0.929399 -0.506494 -0.695652 -0.543779
# 6            38  8YUvk1HD -0.568195  1.319154 -0.456401 -0.746377 -0.694920
# 7            39  cPo3EE0z -0.830075  1.319154 -0.456401 -0.746377 -0.694920
# 8            40  YGw3F2p0 -0.942309  0.842539 -0.343228 -0.717391 -0.392494
# 9            41  kUjHzM8N -0.942309  0.842539 -0.343228 -0.717391 -0.392494
# 10           42  gnuHPDnR -0.727194  0.831403 -0.373840 -0.739130 -0.449228
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
columns = data.columns

# %%
print columns
# Out:
# Index([u'Unnamed: 0', u'PIDN', u'pH', u'ELEV', u'REF2', u'BSAN', u'LSTN', u'Infrared01', u'Infrared02', u'Infrared03', u'Infrared04', u'Infrared05'], dtype='object')

# %%
columns[3]
# Out:
# 'ELEV'

# %%
columns[3][3:2]
# Out:
# ''

# %%
pH_data = data['pH']

# %%
print pH_data
# Out:
# 0    -0.044436
# 1    -0.455961
# 2    -0.549490
# 3    -0.951662
# 4    -0.427903
# 5    -1.073249
# 6    -0.568195
# 7    -0.830075
# 8    -0.942309
# 9    -0.942309
# 10   -0.727194
# 11   -1.194836
# 12    0.282914
# 13    0.161327
# 14   -0.727194
# ...
# 721   -0.399844
# 722    0.329678
# 723   -0.306316
# 724    0.170679
# 725   -0.025730
# 726    0.498029
# 727    0.058445
# 728   -0.119259
# 729   -1.279011
# 730    0.142621
# 731    0.105210
# 732   -1.222894
# 733   -1.363187
# 734   -1.316423
# 735   -1.288364
# Name: pH, Length: 736, dtype: float64

# %%
elev_data = data['ELEV']
print elev_data
# Out:
# 0     0.904900
# 1     0.904900
# 2     0.971715
# 3     0.971715
# 4     0.929399
# 5     0.929399
# 6     1.319154
# 7     1.319154
# 8     0.842539
# 9     0.842539
# 10    0.831403
# 11    0.831403
# 12    0.944989
# 13    0.944989
# 14    0.795768
# ...
# 721    1.056347
# 722    1.074165
# 723    1.074165
# 724    1.060802
# 725    1.060802
# 726    1.040757
# 727    1.040757
# 728    1.029621
# 729    1.029621
# 730    1.096437
# 731    1.096437
# 732    1.147661
# 733    1.147661
# 734    1.100891
# 735    1.100891
# Name: ELEV, Length: 736, dtype: float64

# %%
plt.plot(pH_data, elev_data, 'o')
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1236: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
ref2_data = data['REF2']

# %%
plt.plot(pH_data, ref2_data, 'o')

# %%
bsan_data = data['BSAN']

# %%
plt.plot(pH_data, bsan_data, 'o')

# %%
lstn_data = data['LSTN']

# %%
plt_plot(pH_data, lstn_data, 'o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-283567b4849f> in <module>()
# ----> 1 plt_plot(pH_data, lstn_data, 'o')
#
# NameError: name 'plt_plot' is not defined

# %%
plt.plot(pH_data, lstn_data, 'o')

# %%
infrared01_data = data['Infrared01']
plt.plot(pH_data, infrared01_data, 'o')

# %%
infrared02_data = data['Infrared02']
plt.plot(pH_data, infrared02_data, 'o')

# %%
infrared03_data = data['Infrared03']
plt.plot(pH_data, infrared03_data, 'o')

# %%
infrared04_data = data['Infrared04']
plt.plot(pH_data, infrared04_data, 'o')

# %%
infrared05_data = data['Infrared05']
plt.plot(pH_data, infrared05_data, 'o')

# %%
plt.plot(elev_data, pH_data, 'o')

# %%
plt.plot(infrared04_data, pH_data, 'o')

# %%
plt.plot(infrared02_data, pH_data, 'o')

# %%
data.describe()
# Out:
#        Unnamed: 0          pH        ELEV        REF2        BSAN        LSTN  \
# count  736.000000  736.000000  736.000000  736.000000  736.000000  736.000000
# mean   399.500000    0.019585    0.403813   -0.429374   -0.563376   -0.011037
# std    212.609188    0.964509    1.607167    0.329725    0.209979    0.958168
# min     32.000000   -1.886946   -1.326726   -1.642857   -1.007246   -2.720276
# 25%    215.750000   -0.717841   -1.050557   -0.657699   -0.695652   -0.448294
# 50%    399.500000   -0.137964   -0.166370   -0.442486   -0.586957    0.089564
# 75%    583.250000    0.455941    1.365367   -0.205937   -0.449275    0.750153
# max    767.000000    2.480832    4.891537    0.335807    0.217391    1.519218
#
#        Infrared01  Infrared02  Infrared03  Infrared04  Infrared05
# count  736.000000  736.000000  736.000000  736.000000  736.000000
# mean     0.307313    0.070904    1.315295    1.776879    1.494852
# std      0.092668    0.041800    0.253520    0.175960    0.159071
# ...

# %%
data.corr()
# Out:
#             Unnamed: 0        pH      ELEV      REF2      BSAN      LSTN  \
# Unnamed: 0    1.000000  0.001341  0.099773 -0.130678 -0.171580 -0.235636
# pH            0.001341  1.000000  0.176186 -0.300895  0.299121 -0.219313
# ELEV          0.099773  0.176186  1.000000 -0.496091 -0.463918 -0.880093
# REF2         -0.130678 -0.300895 -0.496091  1.000000  0.489005  0.543130
# BSAN         -0.171580  0.299121 -0.463918  0.489005  1.000000  0.377920
# LSTN         -0.235636 -0.219313 -0.880093  0.543130  0.377920  1.000000
# Infrared01    0.053615  0.105399  0.480666 -0.254778 -0.357432 -0.413861
# Infrared02   -0.086192  0.556729  0.232696 -0.231947  0.265897 -0.182222
# Infrared03   -0.308202 -0.080019 -0.062068  0.181667  0.162113  0.128976
# Infrared04    0.121432 -0.267116 -0.410551  0.168279  0.151414  0.262317
# Infrared05   -0.243771  0.054529  0.458919 -0.269370 -0.292186 -0.335978
#
#             Infrared01  Infrared02  Infrared03  Infrared04  Infrared05
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = linreg.fit(infrared02_data, pH_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-968f3a53ebd0> in <module>()
# ----> 1 reg = linreg.fit(infrared02_data, pH_data)
#
# TypeError: unbound method fit() must be called with LinearRegression instance as first argument (got Series instance instead)

# %%
import sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg
# Out:
# sklearn.linear_model.base.LinearRegression

# %%
reg = LinearRegression.fit(infrared02_data, pH_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-658857f99739> in <module>()
# ----> 1 reg = LinearRegression.fit(infrared02_data, pH_data)
#
# TypeError: unbound method fit() must be called with LinearRegression instance as first argument (got Series instance instead)

# %%
linreg.fit(data[['Infrared02']], data['pH'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-2170f3dcf576> in <module>()
# ----> 1 linreg.fit(data[['Infrared02']], data['pH'])
#
# TypeError: unbound method fit() must be called with LinearRegression instance as first argument (got DataFrame instance instead)

# %%
from sklearn import linear_model

# %%
lr = linear_model.LinearRegression()

# %%
reg = lr.fit(infrared02_data, pH_data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-364238fac732> in <module>()
# ----> 1 reg = lr.fit(infrared02_data, pH_data)
#
# /usr/local/lib/python2.7/dist-packages/sklearn/linear_model/base.pyc in fit(self, X, y, n_jobs)
#     353
#     354         X, y, X_mean, y_mean, X_std = self._center_data(
# --> 355             X, y, self.fit_intercept, self.normalize, self.copy_X)
#     356
#     357         if sp.issparse(X):
#
# /usr/local/lib/python2.7/dist-packages/sklearn/linear_model/base.pyc in center_data(X, y, fit_intercept, normalize, copy, sample_weight)
#     102                 X /= X_std
#     103             else:
# --> 104                 X_std = np.ones(X.shape[1])
#     105         y_mean = np.average(y, axis=0, weights=sample_weight)
#     106         y = y - y_mean
#
# IndexError: tuple index out of range

# %%
cov = data.cov()
