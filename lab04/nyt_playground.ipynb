# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("nyt1.csv")

# %%
data_bits = []
for x in range(2,31):
    str = "http://stat.columbia.edu/~rachel/datasets/nyt%d.csv" % (x)
    data = pd.concat([data, pd.read_csv(str)])

# %%
data
# Out:
#         Age  Gender  Impressions  Clicks  Signed_In
# 0        36       0            3       0          1
# 1        73       1            3       0          1
# 2        30       0            3       0          1
# 3        49       1            3       0          1
# 4        47       1           11       0          1
# 5        47       0           11       1          1
# 6         0       0            7       1          0
# 7        46       0            5       0          1
# 8        16       0            3       0          1
# 9        52       0            4       0          1
# 10        0       0            8       1          0
# 11       21       0            3       0          1
# 12        0       0            4       0          0
# 13       57       0            6       0          1
# 14       31       0            5       0          1
# 15        0       0            6       0          0
# 16       40       1            3       0          1
# ...

# %%
data
# Out:
#         Age  Gender  Impressions  Clicks  Signed_In
# 0        36       0            3       0          1
# 1        73       1            3       0          1
# 2        30       0            3       0          1
# 3        49       1            3       0          1
# 4        47       1           11       0          1
# 5        47       0           11       1          1
# 6         0       0            7       1          0
# 7        46       0            5       0          1
# 8        16       0            3       0          1
# 9        52       0            4       0          1
# 10        0       0            8       1          0
# 11       21       0            3       0          1
# 12        0       0            4       0          0
# 13       57       0            6       0          1
# 14       31       0            5       0          1
# 15        0       0            6       0          0
# 16       40       1            3       0          1
# ...

# %%
data.dropna()
# Out:
#         Age  Gender  Impressions  Clicks  Signed_In
# 0        36       0            3       0          1
# 1        73       1            3       0          1
# 2        30       0            3       0          1
# 3        49       1            3       0          1
# 4        47       1           11       0          1
# 5        47       0           11       1          1
# 6         0       0            7       1          0
# 7        46       0            5       0          1
# 8        16       0            3       0          1
# 9        52       0            4       0          1
# 10        0       0            8       1          0
# 11       21       0            3       0          1
# 12        0       0            4       0          0
# 13       57       0            6       0          1
# 14       31       0            5       0          1
# 15        0       0            6       0          0
# 16       40       1            3       0          1
# ...

# %%
data.corr()
# Out:
#                   Age    Gender  Impressions    Clicks  Signed_In
# Age          1.000000  0.419704    -0.000490 -0.069428   0.846055
# Gender       0.419704  1.000000    -0.000799 -0.060901   0.538353
# Impressions -0.000490 -0.000799     1.000000  0.137203  -0.000603
# Clicks      -0.069428 -0.060901     0.137203  1.000000  -0.107558
# Signed_In    0.846055  0.538353    -0.000603 -0.107558   1.000000

# %%
newData = data[data.Age>0]

# %%
plt.plot( newData['Clicks'], newData['Impressions'], 'o')
